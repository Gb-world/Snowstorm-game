# %% [markdown]
# You went for winter fishing at a lake as your relaxation activity. After hours of fishing, you notice an increase in the wind speed. You then checked your weather app and saw a deadly snowstorm approaching. You quickly pack your fishing equipment to where you parked your car so you can leave the environment as soon as possible before the snowstorm begins. After packing your fishing equipment, you tried starting your car, and you noticed your car was faulty. You remember that the area you were in is notorious for very deadly snowstorms, and the storm will damage your car, and you will end up suffering from frostbite, which will lead to death. You have to troubleshoot the car problem to the best of your knowledge, possibly detect the error, seek help from the surroundings, repair the car, and leave the vicinity as soon as possible before the snowstorm then return to your family.
# Your body temperatur '(Healt') i 532 degrees Celsius; you have cash o 55 dollars0, a credit card, a phone, a Winter jacket, goggles, a backpack, a water bottle, fishing material, a torchlight, a wallt,eand  a winter bots. Your interactions might include a bartender, an auto mechanic, a cab man, anda  storeattendant.
#
# The available rooms include inside the car, a barn auto workshopiode a usand a hardware storeo You have 1 hour 20 mins before the deadly snowstorm.sey

# %%
class wintergame:
    def __init__(self, temp, time, money):
        self.temp = temp
        self.time = time
        self.money = money
    def red_temp(self): #Function to reduce body temperature
        self.temp -= 5
    def inc_temp(self): #Function to increase body temperature
        self.temp += 3
    def red_time(self): #Function to reduce time
        self.time -= 15
    def inc_money(self, moneygain): #Function to increase money when you gained more money
        self.money = self.money + moneygain
        return self.money
    def red_money(self, cost): #Function to reduce money spent
        self.money = self.money - cost
        return self.money
    def display_status(self): #Function to display the level of backpack content, health, time and temperature
        print('Health:' + str(self.temp) + ' degrees Celsius')
        print('Money:$' + str(self.money))
        print('Time:' + str(self.time) + 'minutes to complete quest')
        print('You have the following items with you:')
        for item in items: #items serves as backpack
            print (item)
    def end_of_game(self): #Function to display end of game message
        print('Congratulations, You were able to escape the snowstorm by repairing your car timely')
        print('You completed the game, you got back to your family')

items = [] #Variable to add items for backpack
x = '  '
snowstorm = wintergame(35, 80, 55) #The starting health, time and money 
init_prompt = 'You were fishing and you noticed there was snowstorm approaching the area you were fishing, you packed your stuff and got to your car'
init_prompt += '\nyou tried starting your car, and you noticed it was faulty'
init_prompt += '\nYou have to find a way to troubleshoot, repair and leave the vicinity before the snowstorm begins to be successful in the game'
print(init_prompt) #Introductory message
print(10*x)

flag = True
while flag or snowstorm.temp < 15 or snowstorm.time < 1 or snowstorm.money < 1:
    prompt1 = 'Press start to begin game'
    prompt1 += '\nPress quit to end game'
    choice1 = input(prompt1)
   
    if choice1.lower() == 'quit':
        print('You quit!')
        flag = False
    elif choice1.lower() not in ('quit', 'start'):
        print('please input the correct choice')
        choice1 = input(prompt1)
    elif choice1.lower() == 'start':
        print('You are now in level 1 of the game')
        print(10*x)
        prompt = 'You have three options'
        prompt += '\nPress A to perform a visual check by opening the bonnet of the car'
        prompt += '\nPress B to use your on board diagnostic apparatus'
        prompt += '\nPress C to stay in your car hoping for the snowstorm to end'
        prompt += '\nPress Z to quit game'
        choice = input(prompt)#Player can only choose one option
        if choice.lower() == 'a':
            print(10*x)
            print('Game over\nDue to the storm, visibility was poor and the bonnet of your car hit you on the head')
            
        elif choice.lower() == 'c':
            print('Game over\nStaying in the car was dangerous, the snowstorm pushed you and the car into the lake')
            
        elif choice.lower() == 'z':
            print('You quit!')
            
        elif choice.lower() not in ('a', 'b', 'c', 'z'):
            print('please input the correct choice')
            choice = input(prompt)
        else:
            print(10*x)
            prompt = 'After using your On Board Diagnostics'
            prompt += '\nYou got to know it was an electrical fault with error code "ANA1001", but your On Board Diagnostics is not the latest'
            prompt += '\nTherefore, it could not pinpoint the exact problem'
            prompt += '\nPress A to seek for external help'
            prompt += '\nPress B to stay in the car'
            prompt += '\nPress Z to quit game'
            choice = input(prompt)
            if choice.lower() == 'b':
                print(10*x)
                print('Game over\nStaying in the car was dangerous, the snowstorm pushed you and the car into the lake')
                
            elif choice.lower() == 'z':
                print(10*x)
                print('You quit!')
                
            elif choice.lower() not in ('a', 'b', 'z'):
                print('please input the correct choice')
                choice = input(prompt)
            else:
                print(10*x)
                prompt = 'To seek for help you need to check the surroundings for possible help center'
                prompt += '\nYou need to pick five items with you to ease seeking for help due to the weather'
                prompt += '\nThe following items can be found in your car in which you can pick from'
                prompt += '\nwaterbottle, winterjacket,  smartphone, goggles, fishing equipment, torchlight, winterboot, wallet, cash, creditcard'
                prompt +='\nNote that you pick one item at a time to add to your backpack'
                print(prompt)
                print(10*x)
                item1 = input('Pick an item').lower()
                items.append(item1)
                item2 = input('Pick an item').lower()
                items.append(item2)
                item3 = input('Pick an item').lower()
                items.append(item3)
                item4 = input('Pick an item').lower()
                items.append(item4)
                item5 = input('Pick an item').lower()
                items.append(item5)

                snowstorm.red_time()
                print('You have ' + str(snowstorm.time) + 'minutes left.')
                print('you completed level 1, to continue the game you are seeking for help with the following items')
                for item in items:
                    print (item)
               
                
                print(10*x)
                print(10*x)

                prompt = 'Do you wish to continue to the next level?'
                prompt += '\nPress Continue to resume game'
                prompt += '\nPress Quit to stop game'
                choice = input(prompt)
                if choice.lower() == 'quit':
                    print(10*x)
                    print('You quit!!')
                    
                elif choice.lower() not in ('quit', 'continue'):
                    print(10*x)
                    print('please input the correct choice')
                    choice = input(prompt)
                elif choice.lower() == 'continue':
                    print(10*x)
                    print('Welcome to level 2') #Beginning of level 2
                    snowstorm.display_status()
                    print(10*x)
                    prompt = 'You have two options'
                    prompt += '\nPress A to walk to the bar closeby to seek for help'
                    prompt += '\nPress B to wave for help from cars driving by'
                    prompt += '\nPress Z to quit game'
                    
                    choice = input(prompt)
                    if choice.lower() == 'b':
                        print(10*x)
                        prompt = 'Game Over'
                        prompt += '\nDue to the storm building up and low visibility, no car stopped for you'
                        prompt += '\nTime elapsed, and you could not repair your car, and you died due to frostbite'
                        print(prompt)
                        
                    elif choice.lower() == 'z':
                        print(10*x)
                        print('You quit!')
                           
                    elif choice.lower() not in ('a', 'b', 'z'):
                        print('please input the correct choice')
                        choice = input(prompt)
                    elif 'goggles' not in items:
                        print(10*x)
                        print('game over')
                        print('You did not carry safety goggles, you were blinded in the storm')
                        
                    elif choice.lower() =='a' and 'goggles' in items:
                        print(10*x)
                        prompt = 'Lucky you took your googles, You walked about a kilometer to seek help inside the bar'
                        prompt += '\nPress A to enter the bar to speak to the bar man'
                        prompt += '\nPress B to stay outside'
                        prompt += '\nPress Z to quit game'
                        choice = input(prompt)
            
                        if 'cash' not in items:
                            print('Game over, you did not pick cash from your car')
                            
                        elif choice.lower() == 'b':
                            print(10*x)
                            prompt = 'Game Over'
                            prompt += '\nTime up, and you could not repair your car, and you died due to frostbite'
                            print(prompt)
                            
                        elif choice.lower() == 'z':
                            print(10*x)
                            print('You quit!')
                               
                        elif choice.lower() not in ('a', 'b', 'z'):
                            print(10*x)
                            print('please input the correct choice')
                            choice = input(prompt)
                        elif choice.lower() =='a':
                            snowstorm.red_temp()
                            print(10*x)
                            print('Your body temperature has reduced to ' + str(snowstorm.temp))
                            prompt = 'Interact with bar man to discuss your predicament'
                            prompt += '\nThe barman was able to give direction to the nearest auto workshop'
                            prompt += '\nThe barman asked what you would like to take from the listed below'
                            prompt += '\nCoffee, Hot chocolate, wraps, sharwarma, cold beer, Pastries.'
                            prompt += '\nPick one'
                            choice = input(prompt)
                            if choice.lower() == 'coffee' or choice.lower() == 'hot chocolate':
                                cost = 10
                                snowstorm.red_money(cost)
                                snowstorm.inc_temp()
                                print(10*x)
                                print('You spent $' + str(cost))
                                print('Your body temperature is: ' + str(snowstorm.temp) + '.')
                                print('You now have:$' + str(snowstorm.money)) 
                            elif choice.lower() in ('wraps', 'sharwarma', 'cold beer', 'pastries'):
                                cost = 25
                                snowstorm.red_money(cost)
                                print(10*x)
                                print('You spent $' + str(cost))
                                print('Your body temperature is: ' + str(snowstorm.temp) + '.')
                                print('You now have:$' + str(snowstorm.money))
                            elif choice.lower() not in ('coffee', 'hot chocolate', 'wraps', 'sharwarma', 'cold beer', 'pastries'):
                                print(10*x)
                                print('please input the correct choice')
                                choice = input(prompt)
                            print(10*x)
                            prompt = 'You are a fan of roulette game and you decided to try the lottery in the bar before moving to the auto workshop'
                            prompt += '\nInput a number between 1 to 10 to get more money'
                            choice = int(input(prompt))
                            try:
                                if choice % 3 == 0:
                                    moneygain = 200
                                    snowstorm.inc_money(moneygain)
                                    print(10*x)
                                    print('You gained extra $' + str(moneygain) + ', your new fund is now '+ str(snowstorm.money))
                                else:
                                    cost = 15
                                    snowstorm.red_money(cost)
                                    print(10*x)
                                    print('you lost your lottery and also lost $' + str(cost))
                            except:
                                print('Enter a valid input')
                            
                            print(10*x)
                            prompt = 'You had a good recuperating time at the bar'
                            prompt += '\nCongratulations, you have passed level 2'
                            prompt += '\nYou can now move into the next level on the quest to repair your car'
                            print(prompt)
                            snowstorm.red_time()
                            print('You have ' + str(snowstorm.time) + 'minutes left.')
                            print(10*x)
                           
                            prompt = 'Do you wish to continue to the next level?'
                            prompt += '\nPress Continue to resume game'
                            prompt += '\nPress Quit to stop game'
                            choice = input(prompt)
                            if choice.lower() == 'quit':
                                print(10*x)
                                print('You quit')
                                
                            elif choice.lower() not in ('quit', 'continue'):
                                print(10*x)
                                print('please input the correct choice')
                                choice = input(prompt)
                            elif choice.lower() == 'continue':
                                print(10*x)
                                print('Welcome to level 3') #Beginning of level 3
                                snowstorm.display_status()
                                print(10*x)

                                prompt = 'You are on your way to the auto workshop as described by the barman'
                                prompt += '\nYou need a phone to navigate your way due to the complexity of the environment'
                                prompt += '\nCheck if you picked your smartphone from the car amongst other items'
                            
                                print(prompt)
                                print(10*x)
                                for item in items:
                                    print(item)
                                prompt = 'Press Yes if you picked your smartphone'
                                prompt += '\nPress No if you forgot to pick your smartphone'
                                choice = input(prompt)
                                if 'smartphone' not in items:
                                    print(10*x)
                                    prompt = 'Game over\nYou got lost trying to navigate your way to the auto workshop'
                                    print(prompt)
                                    
                                else:
                                    snowstorm.red_temp()
                                    print(10*x)
                                    print('Your body temperature has reduced to ' + str(snowstorm.temp))
                                    prompt = 'You navigated to the auto workshop successfully and you had an interaction with the auto mechanic'
                                    prompt += '\nYou entered the workshop and explained your ordeal to the auto mechanic with urgency'
                                    prompt += '\nHe asked for the error code you saw on your OBD, for interpretation'
                                    prompt += '\nRecall the error code from the On Board Diagnostics'
                                    prompt += '\nInput the code below'
                                    choice = input(prompt)
                                    if choice.lower() != 'ana1001':
                                        print(10*x)
                                        prompt = 'Game Over\nYou didnt know the error code and the mechanic could not recommend solution'
                                        print(prompt)
                                        
                                    else:
                                        print(10*x)
                                        prompt = 'Great, of you to provide the code!'
                                        prompt += '\nNow the mechanic has deciphered the fault, and he has explained the solution'
                                        prompt += '\nYou were also directed to a hardware store to buy the replacement part'
                                        prompt += '\nCongratulations you completed level 3'
                                        print(prompt)
                                        snowstorm.red_time()
                                        print('You have ' + str(snowstorm.time) + 'minutes left.')
                                        print(10*x)

                                        prompt = 'Do you wish to continue to the next level?'
                                        prompt += '\nPress Continue to resume game'
                                        prompt += '\nPress Quit to stop game'
                                        choice = input(prompt)
                                        if choice.lower() == 'quit':
                                            print(10*x)
                                            print('You quit')
                                            
                                        elif choice.lower() not in ('quit', 'continue'):
                                            print(10*x)
                                            print('please input the correct choice')
                                            choice = input(prompt)
                                        elif choice.lower() == 'continue':
                                            print(10*x)
                                            print('Welcome to level 4') #Beginning of level 4
                                            print(10*x)
                                            snowstorm.display_status()
                                            print(10*x)
                                            prompt = 'You have to get to the hardware store to purchase the needed part'
                                            prompt += '\nPress A to walk the distance to the hardware store'
                                            prompt += '\nPress B to order a taxi'
                                            prompt += '\nPress Z to quit game'
                                            choice = input(prompt)

                                            if choice.lower() == 'a':
                                                print(10*x)
                                                prompt = 'Game Over'
                                                prompt += 'You were attacked by a bear.'
                                                print(prompt)
                                                #flag = False
                                            elif choice.lower() == 'z':
                                                print(10*x)
                                                print('You quit!')
                                                #flag = False   
                                            elif choice.lower() not in ('a', 'b', 'z'):
                                                print('please input the correct choice')
                                                choice = input(prompt)
                                            elif choice.lower() =='b':
                                                print(10*x)
                                                snowstorm.red_temp()
                                                print('Your body temperature has reduced to ' + str(snowstorm.temp))
                                                print('While waiting for the taxi')
                                                cost = 25
                                                snowstorm.red_money(cost)
                                                print(10*x)
                                                print('You spent $' + str(cost) + 'on taxi')
                                                print('You now have:$' + str(snowstorm.money))
                                                prompt = 'Congratulations, you got to the hardware store'
                                                prompt += '\nYou completed level 4!'
                                                print(prompt)
                                                snowstorm.red_time()
                                                print('You have ' + str(snowstorm.time) + 'minutes left.')
                                                print(10*x)
                                                
                                                prompt = 'Do you wish to continue to the next level?'
                                                prompt += '\nPress Continue to resume game'
                                                prompt += '\nPress Quit to stop game'
                                                choice = input(prompt)
                                                if choice.lower() == 'quit':
                                                    print(10*x)
                                                    print('You quit')
                                                    
                                                elif choice.lower() not in ('quit', 'continue'):
                                                    print(10*x)
                                                    print('please input the correct choice')
                                                    choice = input(prompt)
                                                elif choice.lower() == 'continue':
                                                    print(10*x)
                                                    print('WELCOME TO LEVEL 5') #Beginning of level 5
                                                    snowstorm.display_status()
                                                    print(10*x)
                                                    prompt = 'You are now inside the hardware store, ready to buy the replacement fuse'
                                                    prompt += '\nPress A to quickly shop for fuse due to timeframe'
                                                    prompt += '\nPress B to interact with store attendant'
                                                    prompt += '\nPress Z to quit game'
                                                    choice = input(prompt)
                                                    if snowstorm.money < 200 :
                                                        prompt = 'Game over'
                                                        prompt += '\nYou do not have enough money, try winning the lottery'
                                                        print(prompt)
                                                    elif choice.lower() == 'z':
                                                        print(10*x)
                                                        print('You quit!')    
                                                    elif choice.lower() not in ('a', 'b', 'z'):
                                                        print('please input the correct choice')
                                                        choice = input(prompt)
                                                    elif choice.lower() == 'a':
                                                        print(10*x)
                                                        prompt = 'You saw various versions of the fuse'
                                                        prompt += '\nRanging from 2018, 2019, 2020, 2021, 2022, 2023.'
                                                        prompt += '\nYou can only pick one of the versions due to the amount of money you have'
                                                        fuse_version = input(prompt)
                                                        cost = 200
                                                        snowstorm.red_money(cost)
                                                        print(10*x)
                                                        print('You spent $' + str(cost) + 'on the fuse')
                                                        print('You now have:$' + str(snowstorm.money))

                                                        prompt = 'You took the same taxi back to your car to repair the car'
                                                        prompt += '\nPress A to perform the repair'
                                                        prompt += '\nPress Z to quit'
                                                        choice = input(prompt)
        
                                                        if choice.lower() == 'z':
                                                            print(10*x)
                                                            print('You quit')
                                                            
                                                        elif choice.lower() not in ('a', 'z'):
                                                            print(10*x)
                                                            print('please input the correct choice')
                                                            choice = input(prompt)
                                                        elif choice.lower() == 'a':
                                                            print(10*x)
                                                            prompt = 'Now fix the fuse with the version you bought'
                                                            print(prompt)
                                                            new_fuse = input('what version of fuse did you buy?')
                                                            if fuse_version == '2021' and new_fuse == '2021':
                                                                print(10*x)
                                                                final_prompt = 'Great work!!'
                                                                final_prompt += '\nYou successfully repaired your car before the deadly snowstorm'
                                                                print(final_prompt)
                                                                snowstorm.red_time()
                                                                snowstorm.display_status()
                                                                snowstorm.end_of_game()
                                                            else:
                                                                prompt = 'You chose the wrong fuse'
                                                                prompt += 'Game over'
                                                    elif choice.lower() =='b':
                                                        print(10*x)
                                                        prompt = 'You discussed with the store attendant and he advised you to pick the 2021 version'
                                                        prompt += '\nHe explained that the 2021 version will serve the purpose intended.'
                                                        prompt += '\nPick a version from the shelf ranging from 2018, 2019, 2020, 2021, 2022, 2023.\n'
                                                        fuse_version = input(prompt)
                                                        cost = 200
                                                        snowstorm.red_money(cost)
                                                        print(10*x)
                                                        print('You spent $' + str(cost) + 'on the fuse')
                                                        print('You now have:$' + str(snowstorm.money))
                                                    
                                                           
                                                    
                                                        prompt = 'You took the same taxi back to your car to repair the car'
                                                        prompt += '\nPress A to perform the repair'
                                                        prompt += '\nPress Z to quit'
                                                        choice = input(prompt)
        
                                                        if choice.lower() == 'z':
                                                            print(10*x)
                                                            print('You quit')
                                                            
                                                        elif choice.lower() not in ('a', 'z'):
                                                            print(10*x)
                                                            print('please input the correct choice')
                                                            choice = input(prompt)
                                                        elif choice.lower() == 'a':
                                                            print(10*x)
                                                            prompt = 'Now fix the fuse with the version you bought'
                                                            print(prompt)
                                                            new_fuse = input('what version of fuse did you buy?')
                                                            if fuse_version == '2021' and new_fuse == '2021':
                                                                print(10*x)
                                                                final_prompt = 'Great work!!'
                                                                final_prompt += '\nYou successfully repaired your car before the deadly snowstorm'
                                                                print(final_prompt)
                                                                snowstorm.red_time()
                                                                snowstorm.display_status()
                                                                snowstorm.end_of_game()
                                                            else:
                                                                prompt = 'You chose the wrong fuse'
                                                                prompt += 'Game over'
                                                            

        restart_prompt = 'Do you want to play again?'
        restart_prompt += '\nPress Yes/No'
        restart_choice = input(restart_prompt) #Command to restart game 
        if restart_choice.lower() != 'yes':
            print(10 * x)
            flag = False
        else:
            items = []
            snowstorm = wintergame(35, 50, 55) #The starting health, time and money
            
# An ending message for player
print('Thank you for playing!')
print('Hope you escaped the snowstorm?')
# Out:
# You were fishing and you noticed there was snowstorm approaching the area you were fishing, you packed your stuff and got to your car
# you tried starting your car, and you noticed it was faulty
# You have to find a way to troubleshoot, repair and leave the vicinity before the snowstorm begins to be successful in the game
# Press start to begin game
# Press quit to end game hh
# please input the correct choice
# Press start to begin game
# Press quit to end game start
# Press start to begin game
# Press quit to end game start
# You are now in level 1 of the game
# You have three options
# Press A to perform a visual check by opening the bonnet of the car
# Press B to use your on board diagnostic apparatus
# Press C to stay in your car hoping for the snowstorm to end
# Press Z to quit game A
#
# Game over
# Due to the storm, visibility was poor and the bonnet of your car hit you on the head
# Do you want to play again?
# Press Yes/No Yes
# Press start to begin game
# ...
